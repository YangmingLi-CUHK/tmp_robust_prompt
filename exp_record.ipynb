# %% [markdown]
# Cora
# ####################################################################################
# GPF和GPF Plus在few shot特定攻击上的表现 预训练模型 GraphCL 256 hidden dim 100 epoch
# CUDA_VISIBLE_DEVICES=1
# python MyTask.py \
# --pre_train_model_path './pre_trained_model/Cora.GraphCL.GCN.256hidden_dim.pth' \
# --task NodeTask \
# --dataset_name 'Cora' \
# --preprocess_method 'none' \
# --gnn_type 'GCN' \
# --prompt_type 'GPF' \
# --shot_num 5 \
# --run_split 1 \
# --hid_dim 256 \
# --num_layer 2 \
# --epochs 100 \
# --seed 1 \
# --attack_downstream \
# --attack_method 'Meta_Self-0.0' \
# --specified
#
#
#
# inductive
# run split 1
# seed 1
# Cora
#
# GPF                                             1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.5427          0.6952           0.7028
#                         Meta_Self 0.2           0.1634          0.2490           0.3302
#
#
#
# GPF Plus(pnum 20)                               1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.3667          0.7355           0.7197
#                         Meta_Self 0.2           0.1648          0.1386           0.4819
#
#
#
# All-in-one                                      1 shot          5 shot           10 shot
# answer_epoch 20        Meta_Self 0.0            0.3811          0.6254           0.6499
# prompt_epoch 20        Meta_Self 0.2            0.1912          0.2581           0.3872
# epoch        20
#
#
#
#
# GPPT                                            1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.2928          0.5217           0.4928
#                         Meta_Self 0.2           0.0886          0.0806           0.3702
#
#
#
#
# Edgepred_Gprompt+GPrompt                        1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.4962          0.6834           0.7032
#                         Meta_Self 0.2           0.1061          0.2454           0.4809
#
#
#
#
# tranductive
# run split 1
#
# Cora
#
# GPF                                             1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.3134          0.4248           0.5769
#                         Meta_Self 0.2           0.1271          0.1621           0.2135
#
#
#
#
# GPF Plus(pnum 20)                               1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.2525          0.5321           0.6003
#                         Meta_Self 0.2           0.1903          0.1585           0.2958
#
#
#
# MutiGPrompt(20 epoch)                           1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.4321          0.5701           0.6724
#                         Meta_Self 0.2           0.0971          0.2400           0.4869

# %% [markdown]
# Citeseer
# ####################################################################################
# GPF和GPF Plus在few shot特定攻击上的表现 预训练模型 GraphCL 64 hidden dim 200 epoch
# CUDA_VISIBLE_DEVICES=1
# python MyTask.py \
# --pre_train_model_path './pre_trained_model/Cora.GraphCL.GCN.64hidden_dim.pth' \
# --task NodeTask \
# --dataset_name 'Citeseer' \
# --preprocess_method 'none' \
# --gnn_type 'GCN' \
# --prompt_type 'GPF' \
# --shot_num 5 \
# --run_split 1 \
# --hid_dim 256 \
# --num_layer 2 \
# --epochs 100 \
# --seed 1 \
# --attack_downstream \
# --attack_method 'Meta_Self-0.0' \
# --specified
#
#
#
# inductive
# run split 1
# seed 1
# Citeseer
#
# GPF                                             1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.5243          0.6565           0.7018
#                         Meta_Self 0.2           0.1841          0.1664           0.2284
#
#
#
# GPF Plus(pnum 10)                               1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.5369          0.7067           0.7435
#                         Meta_Self 0.2           0.2521          0.2224           0.1997
#
#
#
# All-in-one                                      1 shot          5 shot           10 shot
# answer_epoch 20        Meta_Self 0.0            0.4821          0.5531           0.5828
# prompt_epoch 20        Meta_Self 0.2            0.1297          0.1563           0.2073
# epoch        20
#
#
#
#
# GPPT                                            1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.3750          0.4577           0.5205
#                         Meta_Self 0.2           0.1825          0.2107           0.2570
#
#
#
#
# Edgepred_Gprompt+GPrompt                        1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.5881          0.6848           0.6656
#                         Meta_Self 0.2           0.1319          0.1200           0.2354
#
#
#
#
# tranductive
# run split 1
#
#
# Citeseer
#
# GPF                                             1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.2769          0.3072           0.4356
#                         Meta_Self 0.2           0.1841          0.2331           0.1326
#
#
#
#
# GPF Plus(pnum 20)                               1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.3165          0.3968           0.4416
#                         Meta_Self 0.2           0.1477          0.1440           0.0817
#
#
#
# MutiGPrompt(20 epoch)                           1 shot          5 shot           10 shot
#                         Meta_Self 0.0           0.2031          0.6016           0.5682
#                         Meta_Self 0.2           0.2215          0.2043           0.2760

# %% [markdown]
# 'Meta_Self-0.25' | shot_num 10 | run_split 1 |
#
#
# 'GPF-Tranductive' train no                   | eva no                        0.3385±0.0000
# 'GPF-Tranductive' train no                   | eva prune  before prompt      0.3142±0.0000    threshold = 0.05
# 'GPF-Tranductive' train no                   | eva prune  after  prompt      0.3330±0.0000    threshold = 0.05
#
# # evaluation dont't need prune
# 'GPF-Tranductive' train prune before prompt  | eva no                        0.4903±0.0000    threshold = 0.6
# 'GPF-Tranductive' train prune before prompt  | eva prune  before prompt      0.3970±0.0000    threshold = 0.6
# 'GPF-Tranductive' train prune before prompt  | eva prune  after  prompt      0.3993±0.0000    threshold = 0.6
#
# # evaluation dont't need prune
# 'GPF-Tranductive' train prune after prompt   | eva no                        0.5074±0.0000    threshold = 0.5
# 'GPF-Tranductive' train prune after prompt   | eva prune  before prompt      0.3845±0.0000    threshold = 0.5
# 'GPF-Tranductive' train prune after prompt   | eva prune  after  prompt      0.3813±0.0000    threshold = 0.5
#
# prune in train important, eva not necessary

# %% [markdown]
# 'Meta_Self-0.25' | shot_num 10 | run_split 1 |
#
#
# 'RobustPrompt-T' train no                   | eva no                         0.3312±0.0000  （all other_pt equal GPF）
# 'RobustPrompt-T' train no                   | eva prune  before prompt
# 'RobustPrompt-T' train no                   | eva prune  after  prompt
#
# 'RobustPrompt-T' train prune before prompt  | eva no
# 'RobustPrompt-T' train prune before prompt  | eva prune  before prompt
# 'RobustPrompt-T' train prune before prompt  | eva prune  after  prompt
#
# 'GPF-Tranductive' train prune after prompt   | eva no
# 'GPF-Tranductive' train prune after prompt   | eva prune  before prompt
# 'GPF-Tranductive' train prune after prompt   | eva prune  after  prompt

# %% [markdown]
# # Cora
#
# self.prompt = RobustPrompt_T(self.input_dim,
#                                 muti_defense_pt_dict={'other_pt': 'random-0.4', 'sim_pt': 0.2, 'degree_pt': 2},
#                                 use_attention=False,
#                                 num_heads=1,
#                                 cosine_constraint=True,
#                                 pt_threshold=0.6,
#                                 temperature=1.0,
#                                 weight_mse=0.1,
#                                 weight_kl=0.8,
#                                 weight_constraint=0.6).to(self.device)
#
# # Citeseer GraphCL num_parts= 5
# self.prompt = RobustPrompt_T(self.input_dim,
#                                 muti_defense_pt_dict={'sim_pt': 0.2, 'degree_pt': 2},
#                                 use_attention=False,
#                                 num_heads=1,
#                                 cosine_constraint=False,
#                                 pt_threshold=0.4,
#                                 temperature=1.0,
#                                 weight_mse=0.2,
#                                 weight_kl=0.8,
#                                 weight_constraint=0.2).to(self.device)
#
# # Coraml GraphCL num_parts= 20
# self.prompt = RobustPrompt_T(self.input_dim,
#                                 muti_defense_pt_dict={ 'sim_pt': 0.2, 'degree_pt': 2},
#                                 use_attention=False,
#                                 num_heads=1,
#                                 cosine_constraint=False,
#                                 pt_threshold=0.2,
#                                 temperature=1.0,
#                                 weight_mse=0.2,
#                                 weight_kl=0.8,
#                                 weight_constraint=0.2).to(self.device)
#
#
# # adaptive Citeseer
